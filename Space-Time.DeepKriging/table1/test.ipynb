# %%
# ============================================================
# Paper-aligned Space-Time.DeepKriging (Table 1 replication)
# - Point prediction with MSE loss
# - 10-fold cross validation (45,000 train / 5,000 test per fold)
# - Proper validation split inside training set (early stopping)
# Output:
#   - Per-fold MSPE_nonstat and MSPE_z
#   - Mean/Std/SEmean across 10 folds
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping


# --------------------
# Global settings
# --------------------
SEED = 2024
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DATA_DIR = Path("../synthetic_ds")
LOC_FILE = "LOC_50000_univariate_spacetime_matern_stationary_1"
Z_FILE = "Z1_50000_univariate_spacetime_matern_stationary_1"

EPOCHS = 350
BATCH_SIZE = 512
PATIENCE = 30
LR = 1e-3

N_TOTAL = 50000
TRAIN_SIZE = 45000
TEST_SIZE = 5000
VAL_FRAC = 0.1
K_FOLDS = 10


# --------------------
# Basis functions
# --------------------
def wendland_c2(d):
    out = np.zeros_like(d, dtype=np.float32)
    m = (d >= 0.0) & (d <= 1.0)
    dm = d[m]
    out[m] = ((1.0 - dm) ** 6) * (35.0 * dm**2 + 18.0 * dm + 3.0) / 3.0
    return out


def build_space_basis(s_xy, grid_sizes=(5, 9, 12), theta_scale=2.5):
    n = s_xy.shape[0]
    cols = []

    for g in grid_sizes:
        knots_1d = np.linspace(0.0, 1.0, g, dtype=np.float32)
        kx, ky = np.meshgrid(knots_1d, knots_1d)
        knots = np.column_stack([kx.ravel(), ky.ravel()]).astype(np.float32)

        spacing = 1.0 / float(g - 1)
        theta = theta_scale * spacing

        nb = knots.shape[0]
        phi = np.zeros((n, nb), dtype=np.float32)

        for j in range(nb):
            d = np.linalg.norm(s_xy - knots[j], axis=1) / (theta + 1e-12)
            phi[:, j] = wendland_c2(d)

        cols.append(phi)

    return np.concatenate(cols, axis=1)


def build_time_basis(t_norm, H_list=(10, 15, 45)):
    cols = []

    for H in H_list:
        knots = np.linspace(0.0, 1.0, H, dtype=np.float32)
        kappa = float(abs(knots[1] - knots[0])) if H >= 2 else 1.0
        diff = (t_norm[:, None] - knots[None, :]) / (kappa + 1e-12)
        cols.append(np.exp(-0.5 * (diff**2)).astype(np.float32))

    return np.concatenate(cols, axis=1)


def remove_all_zero_columns(X):
    return X[:, (X != 0).any(axis=0)]


# --------------------
# Model (MSE)
# --------------------
def build_model(input_dim):
    reg = regularizers.L1L2(l1=1e-5, l2=1e-4)

    model = Sequential([
        Dense(100, activation="relu", kernel_initializer="random_normal",
              kernel_regularizer=reg, input_dim=input_dim),
        Dense(100, activation="relu", kernel_initializer="random_normal",
              kernel_regularizer=reg),

        Dense(100, activation="relu", kernel_initializer="random_normal"),
        Dense(100, activation="relu", kernel_initializer="random_normal"),
        Dense(100, activation="relu", kernel_initializer="random_normal"),
        Dense(100, activation="relu", kernel_initializer="random_normal"),
        Dense(100, activation="relu", kernel_initializer="random_normal"),
        Dense(100, activation="relu", kernel_initializer="random_normal"),

        Dense(50, activation="relu", kernel_initializer="random_normal"),
        Dense(50, activation="relu", kernel_initializer="random_normal"),
        Dense(50, activation="relu", kernel_initializer="random_normal"),
        Dense(50, activation="relu", kernel_initializer="random_normal"),

        Dense(1, kernel_initializer="random_normal"),
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=LR),
        loss="mse"
    )
    return model


# --------------------
# Load data & construct targets
# --------------------
loc = pd.read_csv(DATA_DIR / LOC_FILE, header=None, names=["x", "y", "t"])
z = pd.read_csv(DATA_DIR / Z_FILE, header=None, names=["z"])
df = loc.join(z)

s = df["t"].astype(np.float32) / 1000.0
mu = (
    2.0 * np.sin(15.0 * (s - 0.9))
    * np.cos(-37.0 * (s - 0.9) ** 4)
    + (s - 0.9) / 2.0
).to_numpy(dtype=np.float32)

z_obs = df["z"].to_numpy(dtype=np.float32)
y_nonstat = z_obs + mu


# --------------------
# Build embedding X = [phi_space, phi_time] (stacked)
# --------------------
s_xy = df[["x", "y"]].to_numpy(dtype=np.float32)

t_raw = df["t"].to_numpy(dtype=np.float32)
t_norm = (t_raw - t_raw.min()) / (t_raw.max() - t_raw.min() + 1e-12)
t_norm = t_norm.astype(np.float32)

phi_space = build_space_basis(s_xy, grid_sizes=(5, 9, 12), theta_scale=2.5)
phi_time = build_time_basis(t_norm, H_list=(10, 15, 45))

X_all = remove_all_zero_columns(
    np.concatenate([phi_space, phi_time], axis=1)
).astype(np.float32)

if X_all.shape[0] != N_TOTAL:
    raise ValueError(f"Expected N={N_TOTAL}, got {X_all.shape[0]}")


# --------------------
# Splits: proper validation inside each fold
# --------------------
def train_val_split(train_idx, val_frac, seed):
    rs = np.random.RandomState(seed)
    perm = rs.permutation(train_idx)
    n_val = int(len(perm) * val_frac)
    val_idx = perm[:n_val]
    fit_idx = perm[n_val:]
    return fit_idx, val_idx


def make_kfold_indices(n, k, seed):
    rs = np.random.RandomState(seed)
    perm = rs.permutation(n)
    return np.array_split(perm, k)


# --------------------
# 10-fold CV evaluation (Table 1 protocol)
# --------------------
def run_kfold_cv_mspe(X_all, y_nonstat, z_obs, mu,
                      k_folds=10, train_size=45000, test_size=5000,
                      val_frac=0.1, base_seed=2024):

    folds = make_kfold_indices(len(X_all), k_folds, base_seed + 10000)

    mspe_nonstat_list = []
    mspe_z_list = []

    for k in range(k_folds):
        te = folds[k]
        tr_full = np.concatenate([folds[j] for j in range(k_folds) if j != k], axis=0)

        if tr_full.shape[0] != train_size or te.shape[0] != test_size:
            raise ValueError(f"Fold size mismatch: train={tr_full.shape[0]}, test={te.shape[0]}")

        fit_idx, val_idx = train_val_split(tr_full, val_frac, base_seed + 20000 + k)

        tf.random.set_seed(base_seed + 30000 + k)
        np.random.seed(base_seed + 30000 + k)
        random.seed(base_seed + 30000 + k)

        model = build_model(X_all.shape[1])
        model.fit(
            X_all[fit_idx], y_nonstat[fit_idx],
            validation_data=(X_all[val_idx], y_nonstat[val_idx]),
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            verbose=1,
            callbacks=[EarlyStopping(
                monitor="val_loss",
                patience=PATIENCE,
                restore_best_weights=True
            )]
        )

        y_hat = model.predict(X_all[te], verbose=0).ravel()
        z_hat = y_hat - mu[te]

        mspe_nonstat = mean_squared_error(y_nonstat[te], y_hat)
        mspe_z = mean_squared_error(z_obs[te], z_hat)

        mspe_nonstat_list.append(mspe_nonstat)
        mspe_z_list.append(mspe_z)

        print(
            f"[Fold {k + 1:02d}/{k_folds}] "
            f"MSPE_nonstat={mspe_nonstat:.6f} | "
            f"MSPE_z={mspe_z:.6f}"
        )

    mspe_nonstat_arr = np.array(mspe_nonstat_list, dtype=np.float64)
    mspe_z_arr = np.array(mspe_z_list, dtype=np.float64)

    se_nonstat = mspe_nonstat_arr.std(ddof=1) / np.sqrt(k_folds)
    se_z = mspe_z_arr.std(ddof=1) / np.sqrt(k_folds)

    print("\n=== Summary (10-fold CV) ===")
    print(
        f"Mean MSPE_nonstat = {mspe_nonstat_arr.mean():.6f} "
        f"(Std={mspe_nonstat_arr.std(ddof=1):.6f}, SEmean={se_nonstat:.6f})"
    )
    print(
        f"Mean MSPE_z       = {mspe_z_arr.mean():.6f} "
        f"(Std={mspe_z_arr.std(ddof=1):.6f}, SEmean={se_z:.6f})"
    )

    return mspe_nonstat_arr, mspe_z_arr


mspe_nonstat_arr, mspe_z_arr = run_kfold_cv_mspe(
    X_all, y_nonstat, z_obs, mu,
    k_folds=K_FOLDS,
    train_size=TRAIN_SIZE,
    test_size=TEST_SIZE,
    val_frac=VAL_FRAC,
    base_seed=SEED
)
# Out:
# 2026-01-28 12:18:08.389164: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-28 12:18:08.419575: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-01-28 12:18:08.419610: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-01-28 12:18:08.420350: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-01-28 12:18:08.425181: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-28 12:18:09.295727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2026-01-28 12:18:10.496687: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-01-28 12:18:10.580474: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2256] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Epoch 1/350
# 80/80 [==============================] - 2s 8ms/step - loss: 1.6277 - val_loss: 0.8407
# Epoch 2/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6334 - val_loss: 0.4122
# Epoch 3/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3304 - val_loss: 0.3132
# Epoch 4/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2904 - val_loss: 0.2977
# Epoch 5/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2747 - val_loss: 0.2812
# Epoch 6/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2687 - val_loss: 0.2672
# Epoch 7/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2580 - val_loss: 0.2600
# Epoch 8/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2488 - val_loss: 0.2742
# Epoch 9/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2422 - val_loss: 0.2570
# Epoch 10/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2401 - val_loss: 0.2543
# Epoch 11/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2342 - val_loss: 0.2463
# Epoch 12/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2325 - val_loss: 0.2412
# Epoch 13/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2312 - val_loss: 0.2414
# Epoch 14/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2281 - val_loss: 0.2443
# Epoch 15/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2255 - val_loss: 0.2548
# Epoch 16/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2260 - val_loss: 0.2579
# Epoch 17/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2234 - val_loss: 0.2407
# Epoch 18/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2213 - val_loss: 0.2377
# Epoch 19/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2230 - val_loss: 0.2683
# Epoch 20/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2187 - val_loss: 0.2422
# Epoch 21/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2149 - val_loss: 0.2482
# Epoch 22/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2147 - val_loss: 0.2412
# Epoch 23/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2104 - val_loss: 0.2339
# Epoch 24/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2104 - val_loss: 0.2436
# Epoch 25/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2132 - val_loss: 0.2322
# Epoch 26/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2088 - val_loss: 0.2345
# Epoch 27/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2070 - val_loss: 0.2249
# Epoch 28/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2088 - val_loss: 0.2374
# Epoch 29/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2123 - val_loss: 0.2292
# Epoch 30/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2070 - val_loss: 0.2301
# Epoch 31/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2056 - val_loss: 0.2399
# Epoch 32/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2037 - val_loss: 0.2282
# Epoch 33/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2055 - val_loss: 0.2862
# Epoch 34/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2096 - val_loss: 0.2232
# Epoch 35/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2033 - val_loss: 0.2208
# Epoch 36/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1980 - val_loss: 0.2293
# Epoch 37/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2011 - val_loss: 0.2247
# Epoch 38/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2007 - val_loss: 0.2327
# Epoch 39/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1970 - val_loss: 0.2253
# Epoch 40/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1971 - val_loss: 0.2252
# Epoch 41/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1989 - val_loss: 0.2198
# Epoch 42/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1958 - val_loss: 0.2413
# Epoch 43/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1993 - val_loss: 0.2308
# Epoch 44/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1974 - val_loss: 0.2204
# Epoch 45/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1951 - val_loss: 0.2221
# Epoch 46/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1970 - val_loss: 0.2246
# Epoch 47/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1944 - val_loss: 0.2281
# Epoch 48/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1952 - val_loss: 0.2220
# Epoch 49/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1966 - val_loss: 0.2182
# Epoch 50/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1928 - val_loss: 0.2176
# Epoch 51/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1927 - val_loss: 0.2362
# Epoch 52/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1921 - val_loss: 0.2217
# Epoch 53/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1933 - val_loss: 0.2226
# Epoch 54/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1894 - val_loss: 0.2348
# Epoch 55/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1911 - val_loss: 0.2495
# Epoch 56/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1906 - val_loss: 0.2408
# Epoch 57/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1893 - val_loss: 0.2210
# Epoch 58/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1879 - val_loss: 0.2341
# Epoch 59/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1862 - val_loss: 0.2148
# Epoch 60/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1876 - val_loss: 0.2151
# Epoch 61/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1861 - val_loss: 0.2179
# Epoch 62/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1849 - val_loss: 0.2186
# Epoch 63/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1860 - val_loss: 0.2127
# Epoch 64/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1854 - val_loss: 0.2128
# Epoch 65/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1863 - val_loss: 0.2261
# Epoch 66/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1873 - val_loss: 0.2130
# Epoch 67/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1830 - val_loss: 0.2326
# Epoch 68/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1875 - val_loss: 0.2121
# Epoch 69/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1822 - val_loss: 0.2158
# Epoch 70/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1817 - val_loss: 0.2188
# Epoch 71/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1830 - val_loss: 0.2248
# Epoch 72/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1848 - val_loss: 0.2155
# Epoch 73/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1825 - val_loss: 0.2127
# Epoch 74/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1809 - val_loss: 0.2350
# Epoch 75/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1839 - val_loss: 0.2412
# Epoch 76/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1896 - val_loss: 0.2173
# Epoch 77/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1799 - val_loss: 0.2151
# Epoch 78/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1794 - val_loss: 0.2384
# Epoch 79/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1804 - val_loss: 0.2085
# Epoch 80/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1785 - val_loss: 0.2384
# Epoch 81/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1827 - val_loss: 0.2179
# Epoch 82/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1787 - val_loss: 0.2106
# Epoch 83/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1813 - val_loss: 0.2177
# Epoch 84/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1794 - val_loss: 0.2111
# Epoch 85/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1800 - val_loss: 0.2114
# Epoch 86/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1775 - val_loss: 0.2332
# Epoch 87/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1824 - val_loss: 0.2081
# Epoch 88/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1751 - val_loss: 0.2131
# Epoch 89/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1775 - val_loss: 0.2252
# Epoch 90/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1788 - val_loss: 0.2257
# Epoch 91/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1791 - val_loss: 0.2183
# Epoch 92/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1762 - val_loss: 0.2239
# Epoch 93/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1743 - val_loss: 0.2115
# Epoch 94/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1768 - val_loss: 0.2105
# Epoch 95/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1764 - val_loss: 0.2169
# Epoch 96/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1749 - val_loss: 0.2111
# Epoch 97/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1758 - val_loss: 0.2305
# Epoch 98/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1775 - val_loss: 0.2254
# Epoch 99/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1806 - val_loss: 0.2233
# Epoch 100/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1789 - val_loss: 0.2160
# Epoch 101/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1769 - val_loss: 0.2344
# Epoch 102/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1730 - val_loss: 0.2120
# Epoch 103/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1733 - val_loss: 0.2155
# Epoch 104/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1742 - val_loss: 0.2110
# Epoch 105/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1728 - val_loss: 0.2067
# Epoch 106/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1751 - val_loss: 0.2151
# Epoch 107/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1736 - val_loss: 0.2118
# Epoch 108/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1726 - val_loss: 0.2114
# Epoch 109/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1735 - val_loss: 0.2127
# Epoch 110/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1709 - val_loss: 0.2134
# Epoch 111/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1727 - val_loss: 0.2130
# Epoch 112/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1738 - val_loss: 0.2274
# Epoch 113/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1744 - val_loss: 0.2336
# Epoch 114/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1742 - val_loss: 0.2087
# Epoch 115/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1718 - val_loss: 0.2122
# Epoch 116/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1714 - val_loss: 0.2096
# Epoch 117/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1712 - val_loss: 0.2078
# Epoch 118/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1683 - val_loss: 0.2129
# Epoch 119/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1685 - val_loss: 0.2214
# Epoch 120/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1724 - val_loss: 0.2066
# Epoch 121/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1733 - val_loss: 0.2131
# Epoch 122/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1695 - val_loss: 0.2094
# Epoch 123/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1687 - val_loss: 0.2125
# Epoch 124/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1690 - val_loss: 0.2341
# Epoch 125/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1744 - val_loss: 0.2123
# Epoch 126/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1684 - val_loss: 0.2071
# Epoch 127/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1678 - val_loss: 0.2083
# Epoch 128/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1668 - val_loss: 0.2119
# Epoch 129/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1698 - val_loss: 0.2093
# Epoch 130/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1684 - val_loss: 0.2117
# Epoch 131/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1696 - val_loss: 0.2051
# Epoch 132/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1709 - val_loss: 0.2059
# Epoch 133/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1675 - val_loss: 0.2268
# Epoch 134/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1722 - val_loss: 0.2108
# Epoch 135/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1694 - val_loss: 0.2130
# Epoch 136/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1691 - val_loss: 0.2083
# Epoch 137/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1664 - val_loss: 0.2293
# Epoch 138/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1700 - val_loss: 0.2087
# Epoch 139/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1691 - val_loss: 0.2108
# Epoch 140/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1663 - val_loss: 0.2057
# Epoch 141/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1671 - val_loss: 0.2180
# Epoch 142/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1677 - val_loss: 0.2196
# Epoch 143/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1686 - val_loss: 0.2042
# Epoch 144/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1667 - val_loss: 0.2063
# Epoch 145/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1643 - val_loss: 0.2056
# Epoch 146/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1650 - val_loss: 0.2042
# Epoch 147/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1677 - val_loss: 0.2085
# Epoch 148/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1660 - val_loss: 0.2323
# Epoch 149/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1654 - val_loss: 0.2082
# Epoch 150/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1665 - val_loss: 0.2089
# Epoch 151/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1643 - val_loss: 0.2062
# Epoch 152/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1643 - val_loss: 0.2071
# Epoch 153/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1638 - val_loss: 0.2135
# Epoch 154/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1696 - val_loss: 0.2151
# Epoch 155/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1656 - val_loss: 0.2094
# Epoch 156/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1651 - val_loss: 0.2120
# Epoch 157/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1645 - val_loss: 0.2082
# Epoch 158/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1634 - val_loss: 0.2084
# Epoch 159/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1665 - val_loss: 0.2059
# Epoch 160/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1652 - val_loss: 0.2070
# Epoch 161/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1638 - val_loss: 0.2076
# Epoch 162/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1646 - val_loss: 0.2017
# Epoch 163/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1635 - val_loss: 0.2067
# Epoch 164/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1623 - val_loss: 0.2093
# Epoch 165/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1652 - val_loss: 0.2119
# Epoch 166/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1661 - val_loss: 0.2123
# Epoch 167/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1635 - val_loss: 0.2249
# Epoch 168/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1631 - val_loss: 0.2034
# Epoch 169/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1606 - val_loss: 0.2083
# Epoch 170/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1603 - val_loss: 0.2078
# Epoch 171/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1641 - val_loss: 0.2083
# Epoch 172/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1620 - val_loss: 0.2128
# Epoch 173/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1637 - val_loss: 0.2034
# Epoch 174/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1644 - val_loss: 0.2032
# Epoch 175/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1650 - val_loss: 0.2109
# Epoch 176/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1636 - val_loss: 0.2092
# Epoch 177/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1653 - val_loss: 0.2055
# Epoch 178/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1593 - val_loss: 0.2039
# Epoch 179/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1619 - val_loss: 0.2059
# Epoch 180/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1612 - val_loss: 0.2187
# Epoch 181/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1618 - val_loss: 0.2102
# Epoch 182/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1598 - val_loss: 0.2034
# Epoch 183/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1590 - val_loss: 0.2085
# Epoch 184/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1642 - val_loss: 0.2343
# Epoch 185/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1631 - val_loss: 0.2130
# Epoch 186/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1616 - val_loss: 0.2027
# Epoch 187/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1574 - val_loss: 0.2150
# Epoch 188/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1626 - val_loss: 0.2029
# Epoch 189/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1603 - val_loss: 0.2065
# Epoch 190/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1602 - val_loss: 0.2113
# Epoch 191/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1586 - val_loss: 0.2062
# Epoch 192/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1609 - val_loss: 0.2083
# [Fold 01/10] MSPE_nonstat=0.175391 | MSPE_z=0.175391
# Epoch 1/350
# 80/80 [==============================] - 1s 7ms/step - loss: 1.5915 - val_loss: 0.8028
# Epoch 2/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6988 - val_loss: 0.5778
# Epoch 3/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3570 - val_loss: 0.3330
# Epoch 4/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2901 - val_loss: 0.2967
# Epoch 5/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2739 - val_loss: 0.2829
# Epoch 6/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2611 - val_loss: 0.2788
# Epoch 7/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2501 - val_loss: 0.2770
# Epoch 8/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2472 - val_loss: 0.2736
# Epoch 9/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2409 - val_loss: 0.2750
# Epoch 10/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2379 - val_loss: 0.2860
# Epoch 11/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2340 - val_loss: 0.2638
# Epoch 12/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2302 - val_loss: 0.2569
# Epoch 13/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2286 - val_loss: 0.2580
# Epoch 14/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2241 - val_loss: 0.2495
# Epoch 15/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2240 - val_loss: 0.2474
# Epoch 16/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2241 - val_loss: 0.2503
# Epoch 17/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2200 - val_loss: 0.2479
# Epoch 18/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2156 - val_loss: 0.2468
# Epoch 19/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2167 - val_loss: 0.2455
# Epoch 20/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2118 - val_loss: 0.2471
# Epoch 21/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2141 - val_loss: 0.2476
# Epoch 22/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2134 - val_loss: 0.2454
# Epoch 23/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2108 - val_loss: 0.2368
# Epoch 24/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2056 - val_loss: 0.2411
# Epoch 25/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2053 - val_loss: 0.2757
# Epoch 26/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2080 - val_loss: 0.3268
# Epoch 27/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2116 - val_loss: 0.2534
# Epoch 28/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2058 - val_loss: 0.2412
# Epoch 29/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2053 - val_loss: 0.2393
# Epoch 30/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2018 - val_loss: 0.2723
# Epoch 31/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2067 - val_loss: 0.2843
# Epoch 32/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2012 - val_loss: 0.2572
# Epoch 33/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2021 - val_loss: 0.2325
# Epoch 34/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2006 - val_loss: 0.2363
# Epoch 35/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1988 - val_loss: 0.2345
# Epoch 36/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1991 - val_loss: 0.2307
# Epoch 37/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1961 - val_loss: 0.2471
# Epoch 38/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2023 - val_loss: 0.2339
# Epoch 39/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1956 - val_loss: 0.2464
# Epoch 40/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1971 - val_loss: 0.2348
# Epoch 41/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1978 - val_loss: 0.2456
# Epoch 42/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1973 - val_loss: 0.2334
# Epoch 43/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1922 - val_loss: 0.2377
# Epoch 44/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1932 - val_loss: 0.2261
# Epoch 45/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1961 - val_loss: 0.2284
# Epoch 46/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1939 - val_loss: 0.2423
# Epoch 47/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1929 - val_loss: 0.2541
# Epoch 48/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1920 - val_loss: 0.2270
# Epoch 49/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1930 - val_loss: 0.2314
# Epoch 50/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1921 - val_loss: 0.2280
# Epoch 51/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1888 - val_loss: 0.2331
# Epoch 52/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1920 - val_loss: 0.2293
# Epoch 53/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1910 - val_loss: 0.2286
# Epoch 54/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1901 - val_loss: 0.2277
# Epoch 55/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1903 - val_loss: 0.2258
# Epoch 56/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1881 - val_loss: 0.2327
# Epoch 57/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1865 - val_loss: 0.2461
# Epoch 58/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1894 - val_loss: 0.2220
# Epoch 59/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1860 - val_loss: 0.2264
# Epoch 60/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1864 - val_loss: 0.2367
# Epoch 61/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1869 - val_loss: 0.2300
# Epoch 62/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1868 - val_loss: 0.2296
# Epoch 63/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1843 - val_loss: 0.2242
# Epoch 64/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1840 - val_loss: 0.2204
# Epoch 65/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1844 - val_loss: 0.2312
# Epoch 66/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1851 - val_loss: 0.2457
# Epoch 67/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1882 - val_loss: 0.2295
# Epoch 68/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1852 - val_loss: 0.2242
# Epoch 69/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1822 - val_loss: 0.2265
# Epoch 70/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1844 - val_loss: 0.2196
# Epoch 71/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1806 - val_loss: 0.2252
# Epoch 72/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1807 - val_loss: 0.2245
# Epoch 73/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1807 - val_loss: 0.2276
# Epoch 74/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1873 - val_loss: 0.2208
# Epoch 75/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1816 - val_loss: 0.2548
# Epoch 76/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1805 - val_loss: 0.2237
# Epoch 77/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1885 - val_loss: 0.2194
# Epoch 78/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1781 - val_loss: 0.2526
# Epoch 79/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1803 - val_loss: 0.2299
# Epoch 80/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1806 - val_loss: 0.2194
# Epoch 81/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1798 - val_loss: 0.2184
# Epoch 82/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1780 - val_loss: 0.2190
# Epoch 83/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1797 - val_loss: 0.2607
# Epoch 84/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1787 - val_loss: 0.2153
# Epoch 85/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1782 - val_loss: 0.2181
# Epoch 86/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1778 - val_loss: 0.2205
# Epoch 87/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1775 - val_loss: 0.2167
# Epoch 88/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1761 - val_loss: 0.2357
# Epoch 89/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1794 - val_loss: 0.2239
# Epoch 90/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1771 - val_loss: 0.2189
# Epoch 91/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1774 - val_loss: 0.2200
# Epoch 92/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1766 - val_loss: 0.2248
# Epoch 93/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1766 - val_loss: 0.2156
# Epoch 94/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1734 - val_loss: 0.2165
# Epoch 95/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1740 - val_loss: 0.2282
# Epoch 96/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1747 - val_loss: 0.2193
# Epoch 97/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1768 - val_loss: 0.2338
# Epoch 98/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1779 - val_loss: 0.2257
# Epoch 99/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1784 - val_loss: 0.2240
# Epoch 100/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1779 - val_loss: 0.2271
# Epoch 101/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1740 - val_loss: 0.2153
# Epoch 102/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1753 - val_loss: 0.2175
# Epoch 103/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1736 - val_loss: 0.2123
# Epoch 104/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1719 - val_loss: 0.2285
# Epoch 105/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1727 - val_loss: 0.2168
# Epoch 106/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1718 - val_loss: 0.2153
# Epoch 107/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1774 - val_loss: 0.2235
# Epoch 108/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1726 - val_loss: 0.2185
# Epoch 109/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1719 - val_loss: 0.2134
# Epoch 110/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1690 - val_loss: 0.2210
# Epoch 111/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1739 - val_loss: 0.2145
# Epoch 112/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1720 - val_loss: 0.2122
# Epoch 113/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1715 - val_loss: 0.2158
# Epoch 114/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1712 - val_loss: 0.2300
# Epoch 115/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1732 - val_loss: 0.2209
# Epoch 116/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1720 - val_loss: 0.2157
# Epoch 117/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1696 - val_loss: 0.2189
# Epoch 118/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1709 - val_loss: 0.2200
# Epoch 119/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1716 - val_loss: 0.2133
# Epoch 120/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1728 - val_loss: 0.2339
# Epoch 121/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1724 - val_loss: 0.2124
# Epoch 122/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1694 - val_loss: 0.2125
# Epoch 123/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1688 - val_loss: 0.2146
# Epoch 124/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1692 - val_loss: 0.2166
# Epoch 125/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1690 - val_loss: 0.2169
# Epoch 126/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1733 - val_loss: 0.2126
# Epoch 127/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1677 - val_loss: 0.2185
# Epoch 128/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1661 - val_loss: 0.2152
# Epoch 129/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1691 - val_loss: 0.2196
# Epoch 130/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1704 - val_loss: 0.2158
# Epoch 131/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1668 - val_loss: 0.2111
# Epoch 132/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1667 - val_loss: 0.2152
# Epoch 133/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1690 - val_loss: 0.2112
# Epoch 134/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1675 - val_loss: 0.2154
# Epoch 135/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1689 - val_loss: 0.2177
# Epoch 136/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1682 - val_loss: 0.2309
# Epoch 137/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1694 - val_loss: 0.2121
# Epoch 138/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1663 - val_loss: 0.2270
# Epoch 139/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1667 - val_loss: 0.2128
# Epoch 140/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1675 - val_loss: 0.2224
# Epoch 141/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1657 - val_loss: 0.2226
# Epoch 142/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1664 - val_loss: 0.2135
# Epoch 143/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1670 - val_loss: 0.2130
# Epoch 144/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1664 - val_loss: 0.2113
# Epoch 145/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1646 - val_loss: 0.2130
# Epoch 146/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1683 - val_loss: 0.2177
# Epoch 147/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1650 - val_loss: 0.2140
# Epoch 148/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1671 - val_loss: 0.2174
# Epoch 149/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1660 - val_loss: 0.2158
# Epoch 150/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1667 - val_loss: 0.2171
# Epoch 151/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1677 - val_loss: 0.2177
# Epoch 152/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1629 - val_loss: 0.2076
# Epoch 153/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1644 - val_loss: 0.2157
# Epoch 154/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1650 - val_loss: 0.2359
# Epoch 155/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1697 - val_loss: 0.2140
# Epoch 156/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1631 - val_loss: 0.2148
# Epoch 157/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1645 - val_loss: 0.2126
# Epoch 158/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1647 - val_loss: 0.2168
# Epoch 159/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1618 - val_loss: 0.2145
# Epoch 160/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1647 - val_loss: 0.2112
# Epoch 161/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1630 - val_loss: 0.2161
# Epoch 162/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1654 - val_loss: 0.2146
# Epoch 163/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1638 - val_loss: 0.2141
# Epoch 164/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1645 - val_loss: 0.2205
# Epoch 165/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1647 - val_loss: 0.2130
# Epoch 166/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1633 - val_loss: 0.2145
# Epoch 167/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1675 - val_loss: 0.2141
# Epoch 168/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1611 - val_loss: 0.2210
# Epoch 169/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1623 - val_loss: 0.2124
# Epoch 170/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1614 - val_loss: 0.2138
# Epoch 171/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1654 - val_loss: 0.2233
# Epoch 172/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1645 - val_loss: 0.2190
# Epoch 173/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1635 - val_loss: 0.2123
# Epoch 174/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1630 - val_loss: 0.2228
# Epoch 175/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1626 - val_loss: 0.2167
# Epoch 176/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1644 - val_loss: 0.2319
# Epoch 177/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1617 - val_loss: 0.2084
# Epoch 178/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1619 - val_loss: 0.2132
# Epoch 179/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1613 - val_loss: 0.2527
# Epoch 180/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1648 - val_loss: 0.2102
# Epoch 181/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1596 - val_loss: 0.2124
# Epoch 182/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1601 - val_loss: 0.2134
# [Fold 02/10] MSPE_nonstat=0.182659 | MSPE_z=0.182659
# Epoch 1/350
# 80/80 [==============================] - 1s 7ms/step - loss: 1.5265 - val_loss: 0.7669
# Epoch 2/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6791 - val_loss: 0.5912
# Epoch 3/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.4440 - val_loss: 0.3258
# Epoch 4/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3021 - val_loss: 0.2877
# Epoch 5/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2781 - val_loss: 0.2763
# Epoch 6/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2672 - val_loss: 0.2717
# Epoch 7/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2572 - val_loss: 0.2551
# Epoch 8/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2502 - val_loss: 0.2525
# Epoch 9/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2460 - val_loss: 0.2529
# Epoch 10/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2433 - val_loss: 0.2438
# Epoch 11/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2379 - val_loss: 0.2508
# Epoch 12/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2343 - val_loss: 0.2793
# Epoch 13/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2376 - val_loss: 0.2463
# Epoch 14/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2280 - val_loss: 0.2438
# Epoch 15/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2291 - val_loss: 0.2637
# Epoch 16/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2313 - val_loss: 0.2480
# Epoch 17/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2204 - val_loss: 0.2345
# Epoch 18/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2208 - val_loss: 0.2384
# Epoch 19/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2186 - val_loss: 0.2377
# Epoch 20/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2171 - val_loss: 0.2302
# Epoch 21/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2140 - val_loss: 0.2302
# Epoch 22/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2137 - val_loss: 0.2277
# Epoch 23/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2139 - val_loss: 0.2616
# Epoch 24/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2145 - val_loss: 0.2315
# Epoch 25/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2143 - val_loss: 0.2291
# Epoch 26/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2149 - val_loss: 0.2595
# Epoch 27/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2099 - val_loss: 0.2256
# Epoch 28/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2086 - val_loss: 0.2280
# Epoch 29/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2053 - val_loss: 0.2251
# Epoch 30/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2055 - val_loss: 0.2289
# Epoch 31/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2064 - val_loss: 0.2286
# Epoch 32/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2026 - val_loss: 0.2513
# Epoch 33/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2096 - val_loss: 0.2372
# Epoch 34/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2039 - val_loss: 0.2304
# Epoch 35/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2041 - val_loss: 0.2221
# Epoch 36/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2037 - val_loss: 0.2524
# Epoch 37/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.2058 - val_loss: 0.2245
# Epoch 38/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2030 - val_loss: 0.2306
# Epoch 39/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1989 - val_loss: 0.2184
# Epoch 40/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2004 - val_loss: 0.2226
# Epoch 41/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1971 - val_loss: 0.2210
# Epoch 42/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1992 - val_loss: 0.2271
# Epoch 43/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2013 - val_loss: 0.2244
# Epoch 44/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1997 - val_loss: 0.2404
# Epoch 45/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1957 - val_loss: 0.2233
# Epoch 46/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1956 - val_loss: 0.2311
# Epoch 47/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1962 - val_loss: 0.2251
# Epoch 48/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1952 - val_loss: 0.2198
# Epoch 49/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1973 - val_loss: 0.2279
# Epoch 50/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1936 - val_loss: 0.2307
# Epoch 51/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1961 - val_loss: 0.2188
# Epoch 52/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1915 - val_loss: 0.2359
# Epoch 53/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1918 - val_loss: 0.2216
# Epoch 54/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1911 - val_loss: 0.2188
# Epoch 55/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1934 - val_loss: 0.2198
# Epoch 56/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1939 - val_loss: 0.2214
# Epoch 57/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1884 - val_loss: 0.2166
# Epoch 58/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1881 - val_loss: 0.2148
# Epoch 59/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1877 - val_loss: 0.2354
# Epoch 60/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1881 - val_loss: 0.2238
# Epoch 61/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1890 - val_loss: 0.2173
# Epoch 62/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1888 - val_loss: 0.2151
# Epoch 63/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1890 - val_loss: 0.2150
# Epoch 64/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1881 - val_loss: 0.2181
# Epoch 65/350
# 80/80 [==============================] - 0s 4ms/step - loss: 0.1875 - val_loss: 0.2142
# Epoch 66/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1871 - val_loss: 0.2223
# Epoch 67/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1863 - val_loss: 0.2175
# Epoch 68/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1841 - val_loss: 0.2133
# Epoch 69/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1852 - val_loss: 0.2204
# Epoch 70/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1881 - val_loss: 0.2123
# Epoch 71/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1851 - val_loss: 0.2150
# Epoch 72/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1842 - val_loss: 0.2351
# Epoch 73/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1846 - val_loss: 0.2166
# Epoch 74/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1843 - val_loss: 0.2126
# Epoch 75/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1826 - val_loss: 0.2159
# Epoch 76/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1839 - val_loss: 0.2199
# Epoch 77/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1842 - val_loss: 0.2168
# Epoch 78/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1812 - val_loss: 0.2263
# Epoch 79/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1828 - val_loss: 0.2157
# Epoch 80/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1833 - val_loss: 0.2212
# Epoch 81/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1824 - val_loss: 0.2293
# Epoch 82/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1836 - val_loss: 0.2135
# Epoch 83/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1810 - val_loss: 0.2360
# Epoch 84/350
# ...
# Epoch 86/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1856 - val_loss: 0.2140
# Epoch 87/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1764 - val_loss: 0.2145
# Epoch 88/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1786 - val_loss: 0.2471
# Epoch 89/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1769 - val_loss: 0.2172
# Epoch 90/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1794 - val_loss: 0.2756
# Epoch 91/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1801 - val_loss: 0.2328
# Epoch 92/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1786 - val_loss: 0.2118
# Epoch 93/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1769 - val_loss: 0.2340
# Epoch 94/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1792 - val_loss: 0.2191
# Epoch 95/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1799 - val_loss: 0.2140
# Epoch 96/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1775 - val_loss: 0.2186
# Epoch 97/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1746 - val_loss: 0.2109
# Epoch 98/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1753 - val_loss: 0.2110
# Epoch 99/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1761 - val_loss: 0.2154
# [Fold 09/10] MSPE_nonstat=0.182922 | MSPE_z=0.182922
# Epoch 1/350
# 80/80 [==============================] - 1s 7ms/step - loss: 1.5256 - val_loss: 0.8035
# Epoch 2/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.6873 - val_loss: 0.5879
# Epoch 3/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.3612 - val_loss: 0.3311
# Epoch 4/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2923 - val_loss: 0.2879
# Epoch 5/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2722 - val_loss: 0.2788
# Epoch 6/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2609 - val_loss: 0.2636
# Epoch 7/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2531 - val_loss: 0.2906
# Epoch 8/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2490 - val_loss: 0.2608
# Epoch 9/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2425 - val_loss: 0.2549
# Epoch 10/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2373 - val_loss: 0.2676
# Epoch 11/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2353 - val_loss: 0.2577
# Epoch 12/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2388 - val_loss: 0.2494
# Epoch 13/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2337 - val_loss: 0.2483
# Epoch 14/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2297 - val_loss: 0.2426
# Epoch 15/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2233 - val_loss: 0.2442
# Epoch 16/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2233 - val_loss: 0.2389
# Epoch 17/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2208 - val_loss: 0.2480
# Epoch 18/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2176 - val_loss: 0.2479
# Epoch 19/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2165 - val_loss: 0.2350
# Epoch 20/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2197 - val_loss: 0.2547
# Epoch 21/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2168 - val_loss: 0.2290
# Epoch 22/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2137 - val_loss: 0.2298
# Epoch 23/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2130 - val_loss: 0.2271
# Epoch 24/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2124 - val_loss: 0.2467
# Epoch 25/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2097 - val_loss: 0.2339
# Epoch 26/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2091 - val_loss: 0.2474
# Epoch 27/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2073 - val_loss: 0.2258
# Epoch 28/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2082 - val_loss: 0.2335
# Epoch 29/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2132 - val_loss: 0.2284
# Epoch 30/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2074 - val_loss: 0.2301
# Epoch 31/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2035 - val_loss: 0.2252
# Epoch 32/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2053 - val_loss: 0.2335
# Epoch 33/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2084 - val_loss: 0.2224
# Epoch 34/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2022 - val_loss: 0.2211
# Epoch 35/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1989 - val_loss: 0.2302
# Epoch 36/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2017 - val_loss: 0.2170
# Epoch 37/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2032 - val_loss: 0.2191
# Epoch 38/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1966 - val_loss: 0.2248
# Epoch 39/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2011 - val_loss: 0.2352
# Epoch 40/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.2006 - val_loss: 0.2192
# Epoch 41/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1998 - val_loss: 0.2183
# Epoch 42/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1989 - val_loss: 0.2161
# Epoch 43/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1940 - val_loss: 0.2139
# Epoch 44/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1938 - val_loss: 0.2180
# Epoch 45/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1969 - val_loss: 0.2226
# Epoch 46/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1980 - val_loss: 0.2272
# Epoch 47/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1933 - val_loss: 0.2196
# Epoch 48/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1925 - val_loss: 0.2133
# Epoch 49/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1924 - val_loss: 0.2292
# Epoch 50/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1941 - val_loss: 0.2351
# Epoch 51/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1928 - val_loss: 0.2162
# Epoch 52/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1904 - val_loss: 0.2150
# Epoch 53/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1905 - val_loss: 0.2339
# Epoch 54/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1920 - val_loss: 0.2302
# Epoch 55/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1899 - val_loss: 0.2131
# Epoch 56/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1887 - val_loss: 0.2143
# Epoch 57/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1886 - val_loss: 0.2608
# Epoch 58/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1887 - val_loss: 0.2133
# Epoch 59/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1872 - val_loss: 0.2136
# Epoch 60/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1867 - val_loss: 0.2144
# Epoch 61/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1875 - val_loss: 0.2136
# Epoch 62/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1875 - val_loss: 0.2168
# Epoch 63/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1868 - val_loss: 0.2399
# Epoch 64/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1861 - val_loss: 0.2252
# Epoch 65/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1861 - val_loss: 0.2241
# Epoch 66/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1855 - val_loss: 0.2147
# Epoch 67/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1848 - val_loss: 0.2098
# Epoch 68/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1844 - val_loss: 0.2101
# Epoch 69/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1852 - val_loss: 0.2203
# Epoch 70/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1867 - val_loss: 0.2135
# Epoch 71/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1855 - val_loss: 0.2166
# Epoch 72/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1840 - val_loss: 0.2383
# Epoch 73/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1816 - val_loss: 0.2209
# Epoch 74/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1828 - val_loss: 0.2165
# Epoch 75/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1818 - val_loss: 0.2092
# Epoch 76/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1828 - val_loss: 0.2107
# Epoch 77/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1806 - val_loss: 0.2112
# Epoch 78/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1780 - val_loss: 0.2124
# Epoch 79/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1802 - val_loss: 0.2070
# Epoch 80/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1823 - val_loss: 0.2160
# Epoch 81/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1841 - val_loss: 0.2096
# Epoch 82/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1819 - val_loss: 0.2511
# Epoch 83/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1808 - val_loss: 0.2182
# Epoch 84/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1798 - val_loss: 0.2130
# Epoch 85/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1763 - val_loss: 0.2216
# Epoch 86/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1796 - val_loss: 0.2100
# Epoch 87/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1778 - val_loss: 0.2077
# Epoch 88/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1765 - val_loss: 0.2188
# Epoch 89/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1802 - val_loss: 0.2079
# Epoch 90/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1761 - val_loss: 0.2162
# Epoch 91/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1747 - val_loss: 0.2327
# Epoch 92/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1776 - val_loss: 0.2070
# Epoch 93/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1776 - val_loss: 0.2155
# Epoch 94/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1789 - val_loss: 0.2280
# Epoch 95/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1792 - val_loss: 0.2164
# Epoch 96/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1748 - val_loss: 0.2115
# Epoch 97/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1752 - val_loss: 0.2097
# Epoch 98/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1770 - val_loss: 0.2186
# Epoch 99/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1748 - val_loss: 0.2058
# Epoch 100/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1723 - val_loss: 0.2104
# Epoch 101/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1733 - val_loss: 0.2111
# Epoch 102/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1764 - val_loss: 0.2067
# Epoch 103/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1767 - val_loss: 0.2314
# Epoch 104/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1744 - val_loss: 0.2078
# Epoch 105/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1746 - val_loss: 0.2157
# Epoch 106/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1724 - val_loss: 0.2066
# Epoch 107/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1718 - val_loss: 0.2067
# Epoch 108/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1726 - val_loss: 0.2091
# Epoch 109/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1707 - val_loss: 0.2363
# Epoch 110/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1733 - val_loss: 0.2116
# Epoch 111/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1735 - val_loss: 0.2082
# Epoch 112/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1723 - val_loss: 0.2023
# Epoch 113/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1706 - val_loss: 0.2022
# Epoch 114/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1711 - val_loss: 0.2340
# Epoch 115/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1720 - val_loss: 0.2068
# Epoch 116/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1720 - val_loss: 0.2107
# Epoch 117/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1723 - val_loss: 0.2141
# Epoch 118/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1724 - val_loss: 0.2120
# Epoch 119/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1691 - val_loss: 0.2101
# Epoch 120/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1697 - val_loss: 0.2058
# Epoch 121/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1707 - val_loss: 0.2122
# Epoch 122/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1735 - val_loss: 0.2677
# Epoch 123/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1791 - val_loss: 0.2106
# Epoch 124/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1695 - val_loss: 0.2036
# Epoch 125/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1701 - val_loss: 0.2064
# Epoch 126/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1681 - val_loss: 0.2103
# Epoch 127/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1706 - val_loss: 0.2061
# Epoch 128/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1676 - val_loss: 0.2242
# Epoch 129/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1696 - val_loss: 0.2195
# Epoch 130/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1682 - val_loss: 0.2043
# Epoch 131/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1697 - val_loss: 0.2050
# Epoch 132/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1669 - val_loss: 0.2051
# Epoch 133/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1691 - val_loss: 0.2072
# Epoch 134/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1688 - val_loss: 0.2054
# Epoch 135/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1671 - val_loss: 0.2069
# Epoch 136/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1668 - val_loss: 0.2141
# Epoch 137/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1672 - val_loss: 0.2072
# Epoch 138/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1653 - val_loss: 0.2150
# Epoch 139/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1684 - val_loss: 0.2110
# Epoch 140/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1668 - val_loss: 0.2047
# Epoch 141/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1677 - val_loss: 0.2045
# Epoch 142/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1666 - val_loss: 0.2138
# Epoch 143/350
# 80/80 [==============================] - 0s 5ms/step - loss: 0.1665 - val_loss: 0.2085
# [Fold 10/10] MSPE_nonstat=0.176728 | MSPE_z=0.176728
#
# === Summary (10-fold CV) ===
# Mean MSPE_nonstat = 0.178207 (Std=0.004346, SEmean=0.001374)
# Mean MSPE_z       = 0.178207 (Std=0.004346, SEmean=0.001374)
